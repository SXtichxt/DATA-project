# %%
import numpy as np
import pandas as pd

print("Anaconda พร้อมใช้งานแล้ว 🚀")
# Out:
# Anaconda พร้อมใช้งานแล้ว 🚀

# %%
df = pd.read_csv(r'D:\DATA_Project\customer_feedback_analysis\data_set\customer_feedback.csv')
df.head()
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว   neutral
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 4  27900  2024-01-08

# %%
df.shape
# Out:
# (8, 9)

# %%
df.head(8)
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว   neutral
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 4  27900  2024-01-08
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
df.tail()
# Out:
#   customer_id   age gender product  rating           feedback sentiment  \
# 3        C004  40.0      M  Tablet       5   เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3  เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1     แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4      จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5   คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 3  18900  2024-01-07
# 4  27900  2024-01-08
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
df.sample()
# Out:
#   customer_id   age gender product  rating          feedback sentiment  spend  \
# 3        C004  40.0      M  Tablet       5  เหมาะกับทำงานมาก  positive  18900
#
#          date
# 3  2024-01-07

# %%
df
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว   neutral
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 4  27900  2024-01-08
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'product', 'rating', 'feedback',
#        'sentiment', 'spend', 'date'],
#       dtype='object')

# %%
df["feedback"]
# Out:
# 0    สินค้าดีมาก ใช้งานลื่น
# 1    เครื่องแรง แต่แบตหมดไว
# 2     เครื่องช้าและค้างบ่อย
# 3          เหมาะกับทำงานมาก
# 4         เฉย ๆ ไม่คุ้มราคา
# 5            แย่มาก พังเร็ว
# 6             จอชัด ใช้ง่าย
# 7          คุ้มค่ามาก แนะนำ
# Name: feedback, dtype: object

# %%
df[['feedback','rating']]
# Out:
#                  feedback  rating
# 0  สินค้าดีมาก ใช้งานลื่น       5
# 1  เครื่องแรง แต่แบตหมดไว       4
# 2   เครื่องช้าและค้างบ่อย       2
# 3        เหมาะกับทำงานมาก       5
# 4       เฉย ๆ ไม่คุ้มราคา       3
# 5          แย่มาก พังเร็ว       1
# 6           จอชัด ใช้ง่าย       4
# 7        คุ้มค่ามาก แนะนำ       5

# %%
df[df["rating"] >= 4] # data filtering
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว   neutral
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 3  18900  2024-01-07
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
df['rating'].value_counts() 
df
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว   neutral
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 4  27900  2024-01-08
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
# lambda form
df['sentiment'] = df["rating"].apply(
    lambda x: "positive" if x >= 4 else('negative' if x <= 2 else 'neutral')
    )
df["sentiment"].value_counts()
# Out:
# sentiment
# positive    5
# negative    2
# neutral     1
# Name: count, dtype: int64

# %%
# def form
def convert_sentiment(x):
    if x >= 4:
        return 'positive'
    elif x <= 2:
        return 'negative'
    else:
        return 'neutral'

df['sentiment'] = df['rating'].apply(convert_sentiment)
df[['sentiment','rating']] #จัดข้อมูลเรียบร้อย
# Out:
#   sentiment  rating
# 0  positive       5
# 1  positive       4
# 2  negative       2
# 3  positive       5
# 4   neutral       3
# 5  negative       1
# 6  positive       4
# 7  positive       5

# %%
df.sort_values(by = 'rating', ascending = False) #เรียง ratingจากมากไปน้อย
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว  positive
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 5   9900  2024-01-08
# 2  12900  2024-01-06
# 4  27900  2024-01-08
# 1  28900  2024-01-06
# 6  17500  2024-01-09
# 0  15900  2024-01-05
# 3  18900  2024-01-07
# 7  31900  2024-01-10

# %%
#check missing values
df.isnull().sum()
# Out:
# customer_id    0
# age            1
# gender         0
# product        0
# rating         0
# feedback       0
# sentiment      0
# spend          0
# date           0
# dtype: int64

# %%
df.dropna()# delete missing column
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว  positive
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
df.fillna('unknow')
# Out:
#   customer_id     age gender product  rating                feedback  \
# 0        C001    25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น
# 1        C002    30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว
# 2        C003    22.0      F   Phone       2   เครื่องช้าและค้างบ่อย
# 3        C004    40.0      M  Tablet       5        เหมาะกับทำงานมาก
# 4        C005  unknow      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา
# 5        C006    35.0      M   Phone       1          แย่มาก พังเร็ว
# 6        C007    28.0      F  Tablet       4           จอชัด ใช้ง่าย
# 7        C008    45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ
#
#   sentiment  spend        date
# 0  positive  15900  2024-01-05
# 1  positive  28900  2024-01-06
# 2  negative  12900  2024-01-06
# 3  positive  18900  2024-01-07
# 4   neutral  27900  2024-01-08
# 5  negative   9900  2024-01-08
# 6  positive  17500  2024-01-09
# 7  positive  31900  2024-01-10

# %%
df.groupby('sentiment')["rating"].mean()
# Out:
# sentiment
# negative    1.5
# neutral     3.0
# positive    4.6
# Name: rating, dtype: float64

# %%
df.to_csv('clean_feedback.csv', index = False)

# %%
fd = pd.read_csv(r'D:\DATA_Project\customer_feedback_analysis\data_set\clean_feedback.csv')
fd
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว  positive
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend        date
# 0  15900  2024-01-05
# 1  28900  2024-01-06
# 2  12900  2024-01-06
# 3  18900  2024-01-07
# 4  27900  2024-01-08
# 5   9900  2024-01-08
# 6  17500  2024-01-09
# 7  31900  2024-01-10

# %%
fd['date'] = pd.to_datetime(df['date'])
fd
# Out:
#   customer_id   age gender product  rating                feedback sentiment  \
# 0        C001  25.0      M   Phone       5  สินค้าดีมาก ใช้งานลื่น  positive
# 1        C002  30.0      F  Laptop       4  เครื่องแรง แต่แบตหมดไว  positive
# 2        C003  22.0      F   Phone       2   เครื่องช้าและค้างบ่อย  negative
# 3        C004  40.0      M  Tablet       5        เหมาะกับทำงานมาก  positive
# 4        C005   NaN      F  Laptop       3       เฉย ๆ ไม่คุ้มราคา   neutral
# 5        C006  35.0      M   Phone       1          แย่มาก พังเร็ว  negative
# 6        C007  28.0      F  Tablet       4           จอชัด ใช้ง่าย  positive
# 7        C008  45.0      M  Laptop       5        คุ้มค่ามาก แนะนำ  positive
#
#    spend       date
# 0  15900 2024-01-05
# 1  28900 2024-01-06
# 2  12900 2024-01-06
# 3  18900 2024-01-07
# 4  27900 2024-01-08
# 5   9900 2024-01-08
# 6  17500 2024-01-09
# 7  31900 2024-01-10

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  8 non-null      object
#  1   age          7 non-null      float64
#  2   gender       8 non-null      object
#  3   product      8 non-null      object
#  4   rating       8 non-null      int64
#  5   feedback     8 non-null      object
#  6   sentiment    8 non-null      object
#  7   spend        8 non-null      int64
#  8   date         8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 708.0+ bytes
